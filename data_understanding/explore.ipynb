# %%
import pandas as pd
from pathlib import Path
import sys

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from utils import cfg

# %% [markdown]
# #### HomeCredit Description

# %%
path_description = cfg.get_raw("columns_description")
table_description = pd.read_csv(path_description, encoding='latin1')

# %%
table_description.head()

# %%
TABLE = ['POS_CASH_balance.csv',
         'application_{train|test}.csv',
         'bureau.csv',
         'bureau_balance.csv',
         'credit_card_balance.csv',
         'installments_payments.csv',
         'previous_application.csv']

# %%
with pd.option_context('display.max_rows', None, 'display.max_colwidth', None):
    for table in TABLE:
        print(f"Table {table}")
        df = table_description[table_description["Table"] == table]
        print(f"Total columns: {len(df)}")
        display(df[['Row', 'Description']])
        print("=" * 50)
